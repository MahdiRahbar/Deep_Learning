# %% [markdown]
# For this notebook I have used the information in the following links:
# This [stack overflow](https://stackoverflow.com/questions/28135436/concatenate-rows-of-two-dataframes-in-pandas).
# This [user guide from Pandas official website](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html).
# ***********

# %%
import pandas as pd

# %%
df1 = pd.read_csv("./dataset/digi_cleaned_phase2_0_1000.csv")
df2 = pd.read_csv("./dataset/digi_cleaned_phase2_1000_2000.csv")
df3 = pd.read_csv("./dataset/digi_cleaned_phase2_2000_3000.csv")
df4 = pd.read_csv("./dataset/digi_cleaned_phase2_3000_4000.csv")
df5 = pd.read_csv("./dataset/digi_cleaned_phase2_4000_5000.csv")
df6 = pd.read_csv("./dataset/digi_cleaned_phase2_5000_6000.csv")
df7 = pd.read_csv("./dataset/digi_cleaned_phase2_6000_7000.csv")
df8 = pd.read_csv("./dataset/digi_cleaned_phase2_7000_8000.csv")
df9 = pd.read_csv("./dataset/digi_cleaned_phase2_8000_9000.csv")
df10 = pd.read_csv("./dataset/digi_cleaned_phase2_9000_10000.csv")
df11 = pd.read_csv("./dataset/digi_cleaned_phase2_10000_11000.csv")
df12 = pd.read_csv("./dataset/digi_cleaned_phase2_11000_12000.csv")
df13 = pd.read_csv("./dataset/digi_cleaned_phase2_12000_13000.csv")
df14 = pd.read_csv("./dataset/digi_cleaned_phase2_13000_14000.csv")
df15 = pd.read_csv("./dataset/digi_cleaned_phase2_14000_15000.csv")
df16 = pd.read_csv("./dataset/digi_cleaned_phase2_15000_16000.csv")
df17 = pd.read_csv("./dataset/digi_cleaned_phase2_16000_17000.csv")
df18 = pd.read_csv("./dataset/digi_cleaned_phase2_17000_18000.csv")
df19 = pd.read_csv("./dataset/digi_cleaned_phase2_18000_19000.csv")
df20 = pd.read_csv("./dataset/digi_cleaned_phase2_19000_20000.csv")

# %%
df_lists = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20]

# %%
data = pd.concat(df_lists)

# %%
data.head()
# Out:
#                                        product_title    recommend  \
# 0  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  recommended
# 1   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت      no_idea
# 2  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...      no_idea
# 3               لپ تاپ 15 اینچی ایسوس مدل N501VW - A  recommended
# 4             اسپیکر بلوتوثی دیووم مدل Bluetune bean  recommended
#
#                                  title  \
# 0                         واقعاً عالیه
# 1                   گوشی مقرون به صرفه
# 2  ابعاد، استحکام و نگهداری شارژ مناسب
# 3       اقرار بیش از حد در ایراد گرفتن
# 4                            بسیار خوب
#
#                                              comment  \
# 0  سلام، قبل اینکه نظرم رو بگم میخواستم به یک موض...
# 1  همه چیز در رابطه با ظاهر این گوشی بسیار خوب اس...
# 2  اگر ظرفیتش براتون کافیه حتما بخرید.\r\nیه شارژ...
# 3  سلام دوستان،،\r\nمنم مثه بعضی از دوستان قبل از...
# 4  من چند سالی هست که این اسپیکرو خریدم و واقعا ح...
#
# ...

# %%
data.to_csv("./dataset/Phased2_Cleaned_Data.csv",encoding="utf-8",index=None)
