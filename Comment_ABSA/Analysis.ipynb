# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import ast
import requests
import json

# %%
data = pd.read_csv("./dataset/comments.csv")

# %%
# Set ipython's max row display
pd.set_option('display.max_row', 1000)
# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

pd.set_option('display.max_colwidth', -1)

# Showing the first 5 rows of our dataframe
data.head()
# Out:
#    product_id                                                   product_title  \
# 0  3692        ماوس بی‌سیم لاجیتک مدل M325
# 1  90213       شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت
# 2  59473       یدک پولیشر میکروفایبر مهسان مدل 20119
# 3  120499      گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت
# 4  67200       شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپر ساعت
#
#   title_en  user_id  likes  dislikes verification_status        recommend  \
# 0  IT       989472   0      0         verified            \N
# 1  AC       3862150  4      1         verified            recommended
# 2  HW       626843   1      0         verified            not_recommended
# 3  MO       786887   6      11        verified            no_idea
# 4  AC       854531   19     4         verified            no_idea
#
#                                  title  \
# 0  NaN
# 1  واقعاً عالیه
# 2  خیلی سخت حوله اش در میاد
# 3  گوشی مقرون به صرفه
# 4  ابعاد، استحکام و نگهداری شارژ مناسب
#
# ...

# %%
data = data.drop(columns=['product_id','title_en','user_id','likes','dislikes','verification_status'])

# %%
data.head(25)
# Out:
#                                                        product_title  \
# 0   ماوس بی‌سیم لاجیتک مدل M325
# 1   شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت
# 2   یدک پولیشر میکروفایبر مهسان مدل 20119
# 3   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت
# 4   شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپر ساعت
# 5   لپ تاپ 15 اینچی ایسوس مدل N501VW - A
# 6   اسپیکر بلوتوثی دیووم مدل Bluetune bean
# 7   ادو پرفیوم زنانه امپر مدل Chifon حجم 100 میلی لیتر
# 8   ماشین اصلاح صورت رمینگتون مدل MB4555
# 9   فلاسک هنری مدل Virginia Special ظرفیت 1.9 لیتر
# 10  هارددیسک اکسترنال سیگیت مدل Backup Plus Desktop ظرفیت 4 ترابایت
# 11  شمع خودرو ان جی کی مدل BKR6EGP
# 12  ماشین بازی بیبی لند مدل Top Car
# 13  شارژر همراه لنوو با ظرفیت 10400 میلی آمپر ساعت
# 14  خودتراش سیلور مدل M5 Magnum به همراه یک یدک
# 15  فلاسک غذا خودرو بلک اند دکر مدل BDV212F
# 16  کرم نرم کننده دست و صورت آلوئه ورا کاسه ای مای حجم 200 میلی لیتر
# 17  ماساژور بیورر MG80
# ...

# %%
#List unique values in the df['name'] column
print (data.recommend.unique())
# Out:
# ['\\N' 'recommended' 'not_recommended' 'no_idea']

# %%
data.recommend.value_counts()
# Out:
# recommended        36972
# \N                 36382
# not_recommended    16110
# no_idea            10536
# Name: recommend, dtype: int64

# %%
data.dropna(subset=['advantages','disadvantages'],inplace=True)

# %%
data.head()
# Out:
#                                                     product_title  \
# 1  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت
# 3  گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت
# 4  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپر ساعت
# 5  لپ تاپ 15 اینچی ایسوس مدل N501VW - A
# 6  اسپیکر بلوتوثی دیووم مدل Bluetune bean
#
#      recommend                                title  \
# 1  recommended  واقعاً عالیه
# 3  no_idea      گوشی مقرون به صرفه
# 4  no_idea      ابعاد، استحکام و نگهداری شارژ مناسب
# 5  recommended  اقرار بیش از حد در ایراد گرفتن
# 6  recommended  بسیار خوب
#
# ...

# %%
data.recommend.value_counts()
# Out:
# recommended        11638
# \N                 10778
# not_recommended    4438
# no_idea            3294
# Name: recommend, dtype: int64

# %%
data = data.drop(data.index[data["recommend"]=='\\N'])

# %%
data.recommend.value_counts()
# Out:
# recommended        11638
# not_recommended    4438
# no_idea            3294
# Name: recommend, dtype: int64

# %%
data.iloc[1].advantages
# Out:
# '["صفحه نمایش پرنور و با کیفیت\\r","کیفیت بالای ساخت\\r","باتری با دوام\\r","حسگر اثر انگشت\\r","2 سیم کارت و شیار کارت حافظه مجزا"]'

# %%
x = ast.literal_eval(data.iloc[1].advantages)
x
# Out:
# ['صفحه نمایش پرنور و با کیفیت\r',
#  'کیفیت بالای ساخت\r',
#  'باتری با دوام\r',
#  'حسگر اثر انگشت\r',
#  '2 سیم کارت و شیار کارت حافظه مجزا']

# %%
def callApi(url, data, tokenKey):
    headers = {
        'Content-Type': "application/json",
        'Authorization': "Bearer " + tokenKey,
        'Cache-Control': "no-cache"
    }
    response = requests.request("POST", url, data=data.encode("utf-8"), headers=headers)
    return response.text

##################### Get Token by Api Key ##########################


baseUrl = "http://api.text-mining.ir/api/"
url = baseUrl + "Token/GetToken"
querystring = {"apikey":"ff2640ed-f32e-ea11-80eb-98ded002619b"}
response = requests.request("GET", url, params=querystring)
_data = json.loads(response.text)
tokenKey = _data['token']

# %%
tokenKey
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..wij7c6XUGs0ZVM4TT0AlifdZ6ZhrE_NVqyFyllGyRqs'

# %%
url =  baseUrl + "PosTagger/GetPos"

payload = u'\"{0}\"'.format(x[0])

result = json.loads(callApi(url, payload, tokenKey))
for phrase in result:
    print("("+phrase['word']+","+phrase['tags']['POS']['item1']+") ")
# Out:
# (صفحه,N)
# (نمایش,N)
# (پرنور,ADJ)
# (و,CON)
# (با‌کیفیت,N)
# (.,)
