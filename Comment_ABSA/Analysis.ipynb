# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./dataset/comments.csv")

# %%
# Set ipython's max row display
pd.set_option('display.max_row', 1000)
# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

pd.set_option('display.max_colwidth', -1)

# Showing the first 5 rows of our dataframe
data.head()
# Out:
#                                                     product_title  \
# 0  ماوس بی‌سیم لاجیتک مدل M325
# 1  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت
# 2  یدک پولیشر میکروفایبر مهسان مدل 20119
# 3  گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت
# 4  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپر ساعت
#
#          recommend                                title  \
# 0  \N               NaN
# 1  recommended      واقعاً عالیه
# 2  not_recommended  خیلی سخت حوله اش در میاد
# 3  no_idea          گوشی مقرون به صرفه
# 4  no_idea          ابعاد، استحکام و نگهداری شارژ مناسب
#
# ...

# %%
data = data.drop(columns=['product_id','title_en','user_id','likes','dislikes','verification_status'])

# %%
data.head(25)
# Out:
#                                         product_title        recommend  \
# 0                         ماوس بی‌سیم لاجیتک مدل M325               \N
# 1   شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...      recommended
# 2               یدک پولیشر میکروفایبر مهسان مدل 20119  not_recommended
# 3    گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت          no_idea
# 4   شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...          no_idea
# 5                لپ تاپ 15 اینچی ایسوس مدل N501VW - A      recommended
# 6              اسپیکر بلوتوثی دیووم مدل Bluetune bean      recommended
# 7   ادو پرفیوم زنانه امپر مدل Chifon حجم 100 میلی ...               \N
# 8                ماشین اصلاح صورت رمینگتون مدل MB4555               \N
# 9      فلاسک هنری مدل Virginia Special ظرفیت 1.9 لیتر          no_idea
# 10  هارددیسک اکسترنال سیگیت مدل Backup Plus Deskto...      recommended
# 11                     شمع خودرو ان جی کی مدل BKR6EGP               \N
# ...

# %%
#List unique values in the df['name'] column
print (data.recommend.unique())
# Out:
# ['\\N' 'recommended' 'not_recommended' 'no_idea']

# %%
data.recommend.value_counts()
# Out:
# recommended        36972
# \N                 36382
# not_recommended    16110
# no_idea            10536
# Name: recommend, dtype: int64
